# %% [markdown]
# # EDA for the HTI data from Harvard Dataverse

# %%
#imports
from __future__ import print_function, division

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

#import datatime

# %matplotlib inline

# %%
ls
# Out:
# README.md       Untitled.ipynb  data/           local/

# %%
ls data/
# Out:
# HTI 00-11 stata12.tab  HTI 00-11 stata13.dta  HTI Codebook 2013.pdf

# %%
hti_df = pd.read_stata('./data/HTI 00-11 stata13.dta')

# %%
hti_df.head()
# Out:
#          country  ccode  year          tier    minstand     efforts  \
# 0  United States    2.0  2001  Special Case  No mention  No mention
# 1  United States    2.0  2002  Special Case  No mention  No mention
# 2  United States    2.0  2003  Special Case  No mention  No mention
# 3  United States    2.0  2004  Special Case  No mention  No mention
# 4  United States    2.0  2005  Special Case  No mention  No mention
#
#    TRAFFICKING_FLOWS source source_order transit      ...            UNP_rat  \
# 0                NaN     No   No mention     Yes      ...       Ê3 Nov 2005Ê
# 1                NaN     No   No mention     Yes      ...       Ê3 Nov 2005Ê
# 2                NaN     No   No mention      No      ...       Ê3 Nov 2005Ê
# 3                NaN     No   No mention      No      ...       Ê3 Nov 2005Ê
# 4                NaN     No   No mention      No      ...       Ê3 Nov 2005Ê
#
#       ILO182 ILO29     ILO105    CEDAW_sign CEDAW_rat    UNCRC_sign  \
# 0 1999-12-02   NaT 1991-09-25  17 Jul 1980Ê            Ê5 Jul 2000Ê
# 1 1999-12-02   NaT 1991-09-25  17 Jul 1980Ê            Ê5 Jul 2000Ê
# 2 1999-12-02   NaT 1991-09-25  17 Jul 1980Ê            Ê5 Jul 2000Ê
# 3 1999-12-02   NaT 1991-09-25  17 Jul 1980Ê            Ê5 Jul 2000Ê
# 4 1999-12-02   NaT 1991-09-25  17 Jul 1980Ê            Ê5 Jul 2000Ê
#
#       UNCRC_rat conflict_sign  conflict_rat
# 0  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 1  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 2  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 3  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 4  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
#
# [5 rows x 67 columns]

# %%
hti_df.columns
# Out:
# Index(['country', 'ccode', 'year', 'tier', 'minstand', 'efforts',
#        'TRAFFICKING_FLOWS', 'source', 'source_order', 'transit',
#        'transit_order', 'destination', 'destination_order', 'internal',
#        'TRAFFICKING_TYPES', 'psource', 'ptransit', 'pdest', 'pinternal',
#        'lsource', 'ltransit', 'ldest', 'linternal', 'dsource', 'dtransit',
#        'ddest', 'dinternal', 'dssource', 'dstransit', 'dsdest', 'dsinternal',
#        'cpsource', 'cptransit', 'cpdest', 'cpinternal', 'clsource',
#        'cltransit', 'cldest', 'clinternal', 'cssource', 'cstransit', 'csdest',
#        'csinternal', 'PROSECUTION', 'domesticlaws', 'enforcement',
#        'convictinfo', 'prosnum', 'PROTECTION', 'protectprogress', 'victimid',
#        'victimservices', 'victimpunish', 'PREVENTION', 'preventprogress',
#        'INTERNATIONAL_LAWS', 'UNP_sign', 'UNP_rat', 'ILO182', 'ILO29',
#        'ILO105', 'CEDAW_sign', 'CEDAW_rat', 'UNCRC_sign', 'UNCRC_rat',
#        'conflict_sign', 'conflict_rat'],
#       dtype='object')

# %%
hti_df.to_csv('test.csv', index=False)
df1 = pd.read_csv('test.csv')
df1.head()
# Out:
#          country  ccode  year          tier    minstand     efforts  \
# 0  United States    2.0  2001  Special Case  No mention  No mention
# 1  United States    2.0  2002  Special Case  No mention  No mention
# 2  United States    2.0  2003  Special Case  No mention  No mention
# 3  United States    2.0  2004  Special Case  No mention  No mention
# 4  United States    2.0  2005  Special Case  No mention  No mention
#
#    TRAFFICKING_FLOWS source source_order transit      ...            UNP_rat  \
# 0                NaN     No   No mention     Yes      ...       Ê3 Nov 2005Ê
# 1                NaN     No   No mention     Yes      ...       Ê3 Nov 2005Ê
# 2                NaN     No   No mention      No      ...       Ê3 Nov 2005Ê
# 3                NaN     No   No mention      No      ...       Ê3 Nov 2005Ê
# 4                NaN     No   No mention      No      ...       Ê3 Nov 2005Ê
#
#        ILO182 ILO29      ILO105    CEDAW_sign CEDAW_rat    UNCRC_sign  \
# 0  1999-12-02   NaN  1991-09-25  17 Jul 1980Ê       NaN  Ê5 Jul 2000Ê
# 1  1999-12-02   NaN  1991-09-25  17 Jul 1980Ê       NaN  Ê5 Jul 2000Ê
# 2  1999-12-02   NaN  1991-09-25  17 Jul 1980Ê       NaN  Ê5 Jul 2000Ê
# 3  1999-12-02   NaN  1991-09-25  17 Jul 1980Ê       NaN  Ê5 Jul 2000Ê
# 4  1999-12-02   NaN  1991-09-25  17 Jul 1980Ê       NaN  Ê5 Jul 2000Ê
#
#       UNCRC_rat conflict_sign  conflict_rat
# 0  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 1  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 2  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 3  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
# 4  23 Dec 2002Ê  Ê5 Jul 2000Ê  23 Dec 2002Ê
#
# [5 rows x 67 columns]
